# %%
import resume_task as rt

# %%
data_files = rt.data_extraction('/home/jovyan/work/Pandas_Classes/resume')

# %%
data = data_files.extract_links()

# %%
data.Links
# Out:
# array([['3+.pdf', None, None, None, None],
#        ['20.pdf', None, None, None, None],
#        ['6+.pdf', None, None, None, None],
#        ['3+.docx', None, None, None, None],
#        ['freasher 1.rtf',
#         'https://github.com/PawanKumarA/Google-Stocks.git', None, None,
#         None],
#        ['freasher 1.rtf',
#         'https://github.com/PawanKumarA/Classification.git', None, None,
#         None],
#        ['freasher 1.rtf',
#         'https://github.com/PawanKumarA/sentiment-analysis-.git', None,
#         None, None],
#        ['12+.docx', 'https://github.com/sandeepdasc1',
#         'www.linkedin.com/in/pulavarthy-s-321a92152/',
#         'www.kaggle.com/sandeepdasc1', 'sandeep.dasc1@gmail.com'],
#        ['8+.docx', None, None, None, None],
#        ['5+.pdf', None, None, None, None],
#        ['7+.pdf', None, None, None, None],
#        ['15+.pdf', None, None, None, None],
#        ['5+ .pdf', 'https://github.com/AbhijitManepatil', None, None,
#         None],
# ...

# %%
data.to_DataFrame()
# Out:
#           fileName                                             github  \
# 0           3+.pdf                                               None
# 1           20.pdf                                               None
# 2           6+.pdf                                               None
# 3          3+.docx                                               None
# 4   freasher 1.rtf   https://github.com/PawanKumarA/Google-Stocks.git
# 5   freasher 1.rtf  https://github.com/PawanKumarA/Classification.git
# 6   freasher 1.rtf  https://github.com/PawanKumarA/sentiment-analy...
# 7         12+.docx                    https://github.com/sandeepdasc1
# 8          8+.docx                                               None
# 9           5+.pdf                                               None
# 10          7+.pdf                                               None
# 11         15+.pdf                                               None
# ...
